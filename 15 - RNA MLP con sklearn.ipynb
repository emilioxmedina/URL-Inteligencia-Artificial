# %%
# Cargar modulos
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier

# %%
# Cargar datos
data = sns.load_dataset('iris')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
train, test = train_test_split(data, test_size=0.4, stratify=data['species'], random_state=31)

# %%
x_train = train[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y_train = train['species']
x_test = test[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y_test = test ['species']

# %%
# Crear el modelo
mlp = MLPClassifier(hidden_layer_sizes=(3,3), solver='sgd', learning_rate_init=0.01, max_iter=500)

# %%
# Codificar la variable de respuesta (categorica)
from sklearn.preprocessing import LabelEncoder
codificador = LabelEncoder()

# %%
data['species'] = codificador.fit_transform(data['species'])
species = pd.DataFrame({'species': ['setosa', 'versicolor', 'virginica']})
species
# Out:
#       species
# 0      setosa
# 1  versicolor
# 2   virginica

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
noescalado = x_train.copy()
x_train_array = sc.fit_transform(x_train.values)

# %%
x_train = pd.DataFrame(x_train_array, index=x_train.index, columns=x_train.columns)

# %%
x_test_array = sc.fit_transform(x_test.values)
x_test = pd.DataFrame(x_test_array, index=x_test.index, columns=x_test.columns)

# %%
mlp.fit(x_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(3, 3), learning_rate_init=0.01, max_iter=5000,
#               solver='sgd')

# %%
mlp.coefs_
# Out:
# [array([[ 0.74594935,  0.08408172,  0.20367528],
#         [-0.17592681, -0.8406194 , -1.25776333],
#         [-0.59229078,  0.87304552,  0.57703394],
#         [-0.02385333,  2.36579903,  0.2127166 ]]),
#  array([[ 0.22288598, -0.6297384 ,  0.41236803],
#         [-1.2569747 , -0.85856827,  2.08358869],
#         [ 1.49501202, -1.25340092, -0.30493415]]),
#  array([[-0.08891808,  1.60970607, -0.35689927],
#         [ 1.39998101, -1.80564723, -0.58724201],
#         [-1.62169239, -0.36713427,  1.0255025 ]])]

# %%
from sklearn.metrics import accuracy_score

# %%
mlp.score(x_train, y_train)
# Out:
# 0.9888888888888889

# %%
prediccion_train = mlp.predict(x_train)
prediccion_test = mlp.predict(x_test)

# %%
train_punteo = accuracy_score(prediccion_train, y_train)
test_punteo = accuracy_score(prediccion_test, y_test)

# %%
print('Puntaje de efectividad, grupo de entrenamiento:', train_punteo)
print('Puntaje de efectividad, grupo de pruebas:', test_punteo)
# Out:
# Puntaje de efectividad, grupo de entrenamiento: 0.9888888888888889
# Puntaje de efectividad, grupo de pruebas: 0.9
